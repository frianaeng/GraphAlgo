# %%
import pandas as pd
import matplotlib.pyplot as plt

title=pd.read_csv("data/title.akas.tsv",sep = "\t")
name=pd.read_csv("data/name.basics.tsv",sep="\t")
criterion=pd.read_csv("data/criterion.csv",sep=",")

# %%
print(title.shape)
print(name.shape)
print(criterion.shape)
# Out:
# (54290886, 8)
# (14768112, 6)
# (1805, 5)

# %%
criterion
# Out:
#       spine                            title             director  \
# 0       1.0                   Grand Illusion          Jean Renoir
# 1       2.0                    Seven Samurai       Akira Kurosawa
# 2       3.0                The Lady Vanishes     Alfred Hitchcock
# 3       4.0                         Amarcord     Federico Fellini
# 4       5.0                    The 400 Blows    François Truffaut
# ...     ...                              ...                  ...
# 1800    NaN                         Mangrove        Steve McQueen
# 1801    NaN                     The Traveler     Abbas Kiarostami
# 1802    NaN  The Gospel According to Matthew  Pier Paolo Pasolini
# 1803    NaN                         Gervaise         René Clément
# 1804    NaN                         Homework     Abbas Kiarostami
#
#               country    year
# 0             France,  1937.0
# 1              Japan,  1954.0
# 2     United Kingdom,  1938.0
# 3              Italy,  1973.0
# 4             France,  1959.0
# ...               ...     ...
# 1800  United Kingdom,  2020.0
# 1801            Iran,  1974.0
# 1802           Italy,  1964.0
# 1803          France,  1956.0
# 1804            Iran,  1989.0
#
# [1805 rows x 5 columns]

# %%
title
# Out:
#             titleId  ordering                      title region language  \
# 0         tt0000001         1                 Carmencita     \N       \N
# 1         tt0000001         2                 Carmencita     DE       \N
# 2         tt0000001         3                 Carmencita     US       \N
# 3         tt0000001         4  Carmencita - spanyol tánc     HU       \N
# 4         tt0000001         5                 Καρμενσίτα     GR       \N
# ...             ...       ...                        ...    ...      ...
# 54290881  tt9916852         7                エピソード #3.20     JP       ja
# 54290882  tt9916852         8             Episodio #3.20     ES       es
# 54290883  tt9916856         1                   The Wind     \N       \N
# 54290884  tt9916856         2                   The Wind     DE       \N
# 54290885  tt9916880         1  Horrid Henry Knows It All     \N       \N
#
#                 types     attributes  isOriginalTitle
# 0            original             \N                1
# 1                  \N  literal title                0
# 2         imdbDisplay             \N                0
# 3         imdbDisplay             \N                0
# 4         imdbDisplay             \N                0
# ...               ...            ...              ...
# 54290881           \N             \N                0
# 54290882           \N             \N                0
# 54290883     original             \N                1
# 54290884  imdbDisplay             \N                0
# 54290885     original             \N                1
#
# [54290886 rows x 8 columns]

# %%
name
# Out:
#              nconst         primaryName birthYear deathYear  \
# 0         nm0000001        Fred Astaire      1899      1987
# 1         nm0000002       Lauren Bacall      1924      2014
# 2         nm0000003     Brigitte Bardot      1934        \N
# 3         nm0000004        John Belushi      1949      1982
# 4         nm0000005      Ingmar Bergman      1918      2007
# ...             ...                 ...       ...       ...
# 14768107  nm9993714   Romeo del Rosario        \N        \N
# 14768108  nm9993716       Essias Loberg        \N        \N
# 14768109  nm9993717  Harikrishnan Rajan        \N        \N
# 14768110  nm9993718         Aayush Nair        \N        \N
# 14768111  nm9993719          Andre Hill        \N        \N
#
#                             primaryProfession  \
# 0                actor,miscellaneous,producer
# 1          actress,soundtrack,archive_footage
# 2           actress,music_department,producer
# 3               actor,writer,music_department
# 4                       writer,director,actor
# ...                                       ...
# 14768107  animation_department,art_department
# 14768108                                   \N
# 14768109                      cinematographer
# 14768110                      cinematographer
# 14768111                                   \N
#
#                                    knownForTitles
# 0         tt0072308,tt0050419,tt0027125,tt0025164
# 1         tt0037382,tt0075213,tt0038355,tt0117057
# 2         tt0057345,tt0049189,tt0056404,tt0054452
# 3         tt0072562,tt0077975,tt0080455,tt0078723
# 4         tt0050986,tt0069467,tt0083922,tt0050976
# ...                                           ...
# 14768107          tt11657662,tt14069590,tt2455546
# 14768108                                       \N
# 14768109                                tt8736744
# 14768110                                tt8736744
# 14768111                                       \N
#
# [14768112 rows x 6 columns]

# %%
filtered_df = title[title["title"].isin(criterion["title"])]

# %%
filtered_df
# Out:
#             titleId  ordering                 title region language  \
# 1060      tt0000225         2  Beauty and the Beast     US       \N
# 1369      tt0000306         2                Hamlet     FR       \N
# 2415      tt0000564         4          Oliver Twist     DK       \N
# 2564      tt0000598         1                Hamlet     \N       \N
# 2565      tt0000598         2                Hamlet     FR       \N
# ...             ...       ...                   ...    ...      ...
# 54275373  tt9910486         1    The Seventh Victim     \N       \N
# 54275640  tt9910622         1              La ronde     \N       \N
# 54286873  tt9914782         1               Weekend     \N       \N
# 54286874  tt9914782         2               Weekend     IT       \N
# 54289596  tt9916086         1     Carnival of Souls     \N       \N
#
#                 types   attributes  isOriginalTitle
# 1060               \N           \N                0
# 1369               \N  short title                0
# 2415      imdbDisplay           \N                0
# 2564         original           \N                1
# 2565      imdbDisplay           \N                0
# ...               ...          ...              ...
# 54275373     original           \N                1
# 54275640     original           \N                1
# 54286873     original           \N                1
# 54286874  imdbDisplay           \N                0
# 54289596     original           \N                1
#
# [57388 rows x 8 columns]

# %%
# build a set of titleIds we care about (fast lookup)
valid_title_ids = set(filtered_df["titleId"])

# function: does this person have at least one matching title?
def has_matching_title(known_for):
    if known_for == r"\N":
        return False
    return any(t in valid_title_ids for t in known_for.split(","))

# filter name dataframe
actors_subset = name[name["knownForTitles"].apply(has_matching_title)]

# %%
actors_subset
# Out:
#              nconst       primaryName birthYear deathYear  \
# 2         nm0000003   Brigitte Bardot      1934        \N
# 4         nm0000005    Ingmar Bergman      1918      2007
# 5         nm0000006    Ingrid Bergman      1915      1982
# 7         nm0000008     Marlon Brando      1924      2004
# 8         nm0000009    Richard Burton      1925      1984
# ...             ...               ...       ...       ...
# 14768065  nm9993670        Ken Hallen        \N        \N
# 14768066  nm9993671    Marko Lampinen        \N        \N
# 14768067  nm9993672  Simone Hulsemann        \N        \N
# 14768068  nm9993673    Petra Jarosova        \N        \N
# 14768069  nm9993674        Kerli Raag        \N        \N
#
#                           primaryProfession  \
# 2         actress,music_department,producer
# 4                     writer,director,actor
# 5               actress,producer,soundtrack
# 7                     actor,director,writer
# 8                   actor,producer,director
# ...                                     ...
# 14768065                             stunts
# 14768066          transportation_department
# 14768067                      miscellaneous
# 14768068                      miscellaneous
# 14768069                      miscellaneous
#
#                                    knownForTitles
# 2         tt0057345,tt0049189,tt0056404,tt0054452
# 4         tt0050986,tt0069467,tt0083922,tt0050976
# 5         tt0034583,tt0038109,tt0036855,tt0038787
# 7         tt0078788,tt0068646,tt0047296,tt0070849
# 8         tt0061184,tt0087803,tt0057877,tt0059749
# ...                                           ...
# 14768065                                tt0969307
# 14768066                                tt0969307
# 14768067                                tt0969307
# 14768068                                tt0969307
# 14768069                                tt0969307
#
# [220374 rows x 6 columns]

# %%
actors_subset = actors_subset[
    actors_subset["primaryProfession"].str.contains(
        r"\bactor\b|\bactress\b",
        case=False,
        na=False
    )
]

# %%
actors_subset
# Out:
#              nconst         primaryName birthYear deathYear  \
# 2         nm0000003     Brigitte Bardot      1934        \N
# 4         nm0000005      Ingmar Bergman      1918      2007
# 5         nm0000006      Ingrid Bergman      1915      1982
# 7         nm0000008       Marlon Brando      1924      2004
# 8         nm0000009      Richard Burton      1925      1984
# ...             ...                 ...       ...       ...
# 14763945  nm9988673        Kevin Rooney        \N        \N
# 14765724  nm9990616        Abraham Neme        \N        \N
# 14766450  nm9991648     Juliette Valdez        \N        \N
# 14766795  nm9992085   Fernando Grediaga        \N        \N
# 14766820  nm9992117  Alexandra McDonald        \N        \N
#
#                           primaryProfession  \
# 2         actress,music_department,producer
# 4                     writer,director,actor
# 5               actress,producer,soundtrack
# 7                     actor,director,writer
# 8                   actor,producer,director
# ...                                     ...
# 14763945                              actor
# 14765724                              actor
# 14766450            actress,writer,producer
# 14766795                              actor
# 14766820            actress,director,writer
#
#                                        knownForTitles
# 2             tt0057345,tt0049189,tt0056404,tt0054452
# 4             tt0050986,tt0069467,tt0083922,tt0050976
# 5             tt0034583,tt0038109,tt0036855,tt0038787
# 7             tt0078788,tt0068646,tt0047296,tt0070849
# 8             tt0061184,tt0087803,tt0057877,tt0059749
# ...                                               ...
# 14763945                                    tt0076995
# 14765724                                    tt3275262
# 14766450  tt16091856,tt12954074,tt12976056,tt23219096
# 14766795                                    tt6155172
# 14766820               tt9618458,tt24328976,tt9083140
#
# [98551 rows x 6 columns]

# %%
actors_subset["primaryProfession"].value_counts().head()
actors_subset.shape
# Out:
# (98551, 6)

# %%
actors_subset.to_csv("data/coarseCriterionActors.csv")
filtered_df.to_csv("data/coarseCriterionMovies.csv")

# %%
from collections import defaultdict
import queue
import copy
import time
class ActorNetwork:

    def __init__(self):
        """ Creates an actor network object """
        self.costars = defaultdict(set) # actor(string) to acted with (set<string>)
        self.movies  = defaultdict(set) # actor(string) to movies starred in (set<string>)
        
    def getNumActors(self): return len(self.costars)
    
    def getNumConnections(self):
        """ Find the number of edges in a given actor network """
        numEdges = 0
        for _,v in self.costars.items(): numEdges += len(v)
        return int(numEdges/2)
                


    def loadDataSet(self, pthToActorFile, pthToMovieFile):

        import pandas as pd
        from collections import defaultdict, deque
    
        # =========================
        # LOAD DATA
        # =========================
        moviedf = pd.read_csv(pthToMovieFile)
        actordf = pd.read_csv(pthToActorFile)
        print(len(actordf))
        # =========================
        # BUILD MOVIE → ACTORS LOOKUP
        # =========================
        movie_to_actors = defaultdict(deque)
    
        for _, row in actordf.iterrows():
            if pd.isna(row["knownForTitles"]):
                continue
            for movie in row["knownForTitles"].split(","):
                movie_to_actors[movie].append(row["primaryName"])
    
        # =========================
        # BUILD NETWORK (SUBSET)
        # =========================
        MAX_MOVIES = 2000    # adjust if needed
        counter = 0
    
        for movie, actors in movie_to_actors.items():
            if len(actors) > 1:   # skip single-actor movies
                self.addMovie(movie, deque(actors))
                counter += 1
    
                if counter % 200 == 0:
                    print(f"{counter} movies processed")
    
                if counter >= MAX_MOVIES:
                    break

        
        
    def addMovie(self, movie, actors):
        """ Add a movie (string) and a set<actors> string to the network """
        processed = set()
        yetToProcess = actors
        #print(yetToProcess)
       # import pdb;pdb.set_trace()
        while yetToProcess: # Is only true when actors is non-empty
            actor = yetToProcess.popleft()
            
            s = set()
            q= copy.deepcopy(yetToProcess)
            while len(q)!=0:
                s.add(q.popleft())
                
            self.costars[actor] = self.costars[actor].union(s).union(processed)
            self.movies[actor].add(movie)
            processed.add(actor)
    
    def _BFS(self,actor):
       # stack=[]
       # stack.append(actor)
        Q = queue.SimpleQueue()
        Q.put(actor)
        parent={}
        visited = {}
        for act in self.costars:
            visited[act]=False
            parent[act]=None
        visited[actor] = True
    
        while(not Q.empty()):
            u = Q.get()
        
            for v in self.costars[u]:
                if(visited[v]==False):
                    parent[v] = u
                    Q.put(v)
                    visited[v]=True
        return parent

            

    def _biBFS(self, actor1, actor2):

        if actor1 not in self.costars or actor2 not in self.costars:
            return False, None, None, None
    
        Q1 = queue.SimpleQueue()
        Q2 = queue.SimpleQueue()
        Q1.put(actor1)
        Q2.put(actor2)
    
        parent1 = {a: None for a in self.costars}
        parent2 = {a: None for a in self.costars}
    
        visited1 = {a: False for a in self.costars}
        visited2 = {a: False for a in self.costars}
    
        visited1[actor1] = True
        visited2[actor2] = True
    
        while not Q1.empty() or not Q2.empty():
    
            # expand from actor1 side
            if not Q1.empty():
                u = Q1.get()
                for v in self.costars[u]:
                    if not visited1[v]:
                        visited1[v] = True
                        parent1[v] = u
                        Q1.put(v)
    
                        if visited2[v]:
                            return True, parent1, parent2, v
    
            # expand from actor2 side
            if not Q2.empty():
                u = Q2.get()
                for v in self.costars[u]:
                    if not visited2[v]:
                        visited2[v] = True
                        parent2[v] = u
                        Q2.put(v)
    
                        if visited1[v]:
                            return True, parent1, parent2, v
    
        return False, parent1, parent2, None
    




    
    def getShortestPath(self,actor1,actor2):
        startT = time.time()
        p = self._BFS(actor1)
       
        if(actor2 not in p):
            print(actor2 +" is not in the database")
            return
        if(p[actor2]==None):
            print(actor2 + " is not connected to "+actor1)
            return
        curract = actor2
        movie = []
        actor = [actor2]
        while(curract!=actor1):
            s= p[curract]
            actor.append(s)
            l = list(self.movies[s].intersection(self.movies[curract]))
            movie.append(l[0])
            curract = s
        endT = time.time()
        print(endT-startT)
        return actor[::-1],movie[::-1]

    def biBFSGetShortestPath(self,actor1,actor2):
        startT = time.time()
        
        if(not actor1 in self.costars):
            print(actor1+ " is not in the database")
        if(not actor2 in self.costars):
            print(actor2 +" is not in the database")
        isPath,p1,p2,x = self._biBFS(actor1,actor2)

        if not isPath:
            return "There is no path from " + actor1 +" to "+actor2
        
        l1=[]
        l2=[]
        m1=[]
        m2=[]
        curract = x
        
        while(curract!=actor1):
            l1.append(curract)
            nextAct= p1[curract]
            l=list(self.movies[nextAct].intersection(self.movies[curract]))
            m1.append(l[0])
            
            curract =p1[curract]
            
        l1 = l1[1:]
        curract=x
        while(curract!=actor2):
            l2.append(curract)
            nextAct= p2[curract]
            l=list(self.movies[nextAct].intersection(self.movies[curract]))
            m2.append(l[0])
            curract=p2[curract]
        actor = [actor1]+l1[::-1] + l2[::-1]+[actor2]
        movie = m1[::-1]+m2[::-1]
        
        endT = time.time()
        print(x)
        print(endT-startT)
        return actor,movie
        
    def visualize_network(self):
        """ Visualize the actor network using NetworkX and Matplotlib """
        G = nx.Graph()
        
        # Add nodes (actors)
        for actor in self.costars:
            G.add_node(actor)
        
        # Add edges (costar relationships)
        for actor, costars in self.costars.items():
            for costar in costars:
                G.add_edge(actor, costar)
        
        # Create a circular layout for visualization
        pos = nx.circular_layout(G)
        
        # Draw the graph
        plt.figure(figsize=(10, 8))
        nx.draw(G, pos, with_labels=True, node_color='lightblue', 
                node_size=500, font_size=8, font_weight='bold', 
                edge_color='gray')
        
        # Add title and display
        plt.title("Actor Network Visualization")
        plt.show()




    def DFS(self,actor):
       # Q = queue.SimpleQueue()
       # Q.put(actor)
        start=time.time()
        stack = []                
        stack.append(actor)

        parent={}
        visited = {}
        for act in self.costars:
            visited[act]=False
            parent[act]=None
        visited[actor] = True
    
        while(not len(stack)==0):
           # u = Q.get()
            u=stack.pop()
            for v in self.costars[u]:
                if(visited[v]==False):
                    parent[v] = u
                    stack.append(v)
                   # Q.put(v)
                    visited[v]=True
        e=time.time()
        tot=e-start
        print(tot)
        return parent

    def DFS_recursive(self, actor):
        start=time.time()
        parent = {}
        visited = {}
    
        for act in self.costars:
            visited[act] = False
            parent[act] = None
    
        def dfs(u):
            visited[u] = True
            for v in self.costars[u]:
                if not visited[v]:
                    parent[v] = u
                    dfs(v)
    
        dfs(actor)
        e=time.time()
        tot=e-start
        print(tot)
        return parent

    
    def countConnectedComponents(self):
        visited = {actor: False for actor in self.costars}
        components = 0
    
        for actor in self.costars:
            if not visited[actor]:
                components += 1
    
                # run DFS from this actor
                stack = [actor]
                visited[actor] = True
    
                while stack:
                    u = stack.pop()
                    for v in self.costars[u]:
                        if not visited[v]:
                            visited[v] = True
                            stack.append(v)
    
        return components

# %%
an=ActorNetwork()
an.DFS("Charles Previn")
an.DFS_recursive("Charles Previn")
print("Connected components:", an.countConnectedComponents()) #if its 1 -- the graph is connected
# Out:
# 1.0967254638671875e-05
# 1.3113021850585938e-05
# Connected components: 1

# %%
import pickle

an = ActorNetwork()
an.loadDataSet("data/coarseCriterionActors.csv",
               "data/coarseCriterionMovies.csv")
an._BFS("actor1")
an._biBFS("actor1","actor2")
with open("data/an.pkl", "wb") as f:
    pickle.dump(an, f)

with open("data/an.pkl", "rb") as f:
    an = pickle.load(f)

#an=ActorNetwork()
#an.loadDataSet("data/coarseCriterionActors.csv","data/coarseCriterionMovies.csv")
# Out:
# 98551
# 200 movies processed
# 400 movies processed
# 600 movies processed
# 800 movies processed
# 1000 movies processed
# 1200 movies processed
# 1400 movies processed
# 1600 movies processed
# 1800 movies processed
# 2000 movies processed

# %%
an.getShortestPath("Brigitte Bardot","Heinz Hopf")
#an.BFS("")
# Out:
# 0.1093449592590332
# (['Brigitte Bardot',
#   'Christian Marquand',
#   'Robert Mitchum',
#   'C. Bakaleinikoff',
#   'Ingrid Bergman',
#   'Heinz Hopf'],
#  ['tt0049189', 'tt0056197', 'tt0039689', 'tt0038787', 'tt0083922'])

# %%
an.biBFSGetShortestPath("Brigitte Bardot","Heinz Hopf")
# Out:
# C. Bakaleinikoff
# 0.004664182662963867
# (['Brigitte Bardot',
#   'Christian Marquand',
#   'Robert Mitchum',
#   'Ingrid Bergman',
#   'C. Bakaleinikoff',
#   'Heinz Hopf'],
#  ['tt0049189', 'tt0056197', 'tt0039689', 'tt0083922', 'tt0038787'])

# %%
an._biBFS("actor1","actor2")
# Out:
# (False, None, None, None)

# %%
len(an.costars.keys())
# Out:
# 23859

# %%
import random
import numpy as np
random.seed(42)

N = 5
times_biBFS = np.empty(N)
times_BFS = np.empty(N)

for i in range(N):
    sample = random.choices(list(an.costars.keys()), k=2)
    actor1,actor2=sample
    start = time.time()
    an.getShortestPath(actor1,actor2)
    end=time.time()
    tot = end-start
    times_BFS[i] = tot

    start = time.time()
    an.biBFSGetShortestPath(actor1,actor2)
    end=time.time()
    tot = end-start
    times_biBFS[i] = tot
# Out:
# 0.10864901542663574
# Forrester Harvey
# 0.003486156463623047
# 0.10396099090576172
# Philippe Morier-Genoud
# 0.003653287887573242
# 0.10487699508666992
# Thomas Jane
# 0.003849029541015625
# 0.10571479797363281
# Jessica Galinas
# 0.004111766815185547
# 0.10414528846740723
# Carlo Savina
# 0.003567218780517578

# %%
print(times_BFS)
print(times_biBFS)
# Out:
# [0.10875487 0.10409498 0.10509109 0.10589027 0.10430789]
# [0.00371194 0.00380874 0.00404096 0.00429392 0.00373411]

# %%
print(np.mean(times_BFS))
print(np.mean(times_biBFS))
# Out:
# 0.10562782287597657
# 0.0039179325103759766

# %%
print(np.mean(times_BFS)/np.mean(times_biBFS))
# Out:
# 26.96009249680521

# %%
print(np.sqrt(np.var(times_BFS)))
print(np.sqrt(np.var(times_biBFS)))
# Out:
# 0.0016868447067971692
# 0.0002212001784028067

# %%
import networkx as nx
import matplotlib.pyplot as plt
def compute_depths(parent, root):
    depth = {root: 0}

    def dfs(u):
        for v, p in parent.items():
            if p == u:
                depth[v] = depth[u] + 1
                dfs(v)

    dfs(root)
    return depth


def visualize_dfs_tree(parent, root):
    T = nx.DiGraph()

    # build DFS tree from parent pointers
    for node, par in parent.items():
        if par is not None:
            T.add_edge(par, node)

    depth = compute_depths(parent, root)

    # manual tree layout
    pos = {}
    x = 0
    for node in sorted(depth, key=lambda v: depth[v]):
        pos[node] = (x, -depth[node])
        x += 1

    plt.figure(figsize=(16, 6))
    nx.draw(
        T,
        pos,
        with_labels=False,
        node_size=700,
        font_size=8,
        arrows=False
    )
    plt.title(f"DFS Tree rooted at {root}")
    plt.show()

# %%
parent = an.DFS("Thomas Jane")
visualize_dfs_tree(parent, "Thomas Jane")
# Out:
# 1.0967254638671875e-05

# %%
#other methods that should be private- DFS,DFS_recursive, countConnectedComponents,getNumActors,getNumConnections

# it does make sense to take the visualizations out of the Actor Network and create a new notebook with a new framework
#for visualizing because the visualizations are what the user may be more interested in seeing rather than everything
#that is running in the background
